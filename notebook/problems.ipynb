# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# NORMAL

# %%
from scipy.stats import norm

# Define all the probability functions related to the normal distribution

def dnorm(x, mean=0, sd=1):
    """
    Calculates the point estimate (density) of the normal distribution
    """
    result = norm.pdf(x, loc=mean, scale=sd)
    return result

def pnorm(q, mean=0, sd=1):
    """
    Calculates the cumulative probability of the normal distribution
    """
    result = norm.cdf(q, loc=mean, scale=sd)
    return result

def qnorm(p, mean=0, sd=1):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(p, loc=mean, scale=sd)
    return result

def rnorm(n, mean=0, sd=1):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc=mean, scale=sd, size=n)
    return result

# %%
print(f"Probability that a Normal(0, 1) takes the value 1: {dnorm(1)}")
print(f"Probability that a Normal(0, 1) takes a value less than 1: {pnorm(1)}")
print(f"Which value of a Normal(0, 1) has a cumulative probability of 0.9? {qnorm(0.9)}")
print(f"Generate 5 random values from a Normal(0, 1) distribution: {rnorm(5)}")
# Out:
# Probability that a Normal(0, 1) takes the value 1: 0.24197072451914337
# Probability that a Normal(0, 1) takes a value less than 1: 0.8413447460685429
# Which value of a Normal(0, 1) has a cumulative probability of 0.9? 1.2815515655446004
# Generate 5 random values from a Normal(0, 1) distribution: [-0.87798259 -0.82688035 -0.22647889  0.36736551  0.91358463]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros para la distribución normal
mean = 0
sd = 1
n_samples = 2000

# Generar datos aleatorios de una distribución normal
data_normal = rnorm(n_samples, mean=mean, sd=sd)

# Calcular PDF, CDF y PPF
pdf_normal = dnorm(data_normal, mean=mean, sd=sd)
cdf_normal = pnorm(data_normal, mean=mean, sd=sd)
ppf_normal = qnorm(cdf_normal, mean=mean, sd=sd)  # El PPF inverso de la CDF debe devolver el valor original

# Crear gráficos
fig, axis = plt.subplots(3, 1, figsize=(7, 10))

axis[0].stem(data_normal[:50], pdf_normal[:50], 'r-')  # Gráfico PDF
axis[0].set_title('PDF - Normal Distribution')

axis[1].stem(data_normal[:50], cdf_normal[:50], 'b-')  # Gráfico CDF
axis[1].set_title('CDF - Normal Distribution')

axis[2].stem(data_normal[:50], ppf_normal[:50], 'g-')  # Gráfico PPF
axis[2].set_title('PPF - Normal Distribution')

# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# UNIFORM

# %%
from scipy.stats import uniform

# Define all the probability functions related to the uniform distribution

def dunif(x, min=0, max=1):
    """
    Calculates the point estimate (density) of the uniform distribution
    """
    result = uniform.pdf(x, loc=min, scale=max-min)
    return result

def punif(q, min=0, max=1):
    """
    Calculates the cumulative probability of the uniform distribution
    """
    result = uniform.cdf(q, loc=min, scale=max-min)
    return result

def qunif(p, min=0, max=1):
    """
    Calculates the quantile function from the uniform distribution
    """
    result = uniform.ppf(p, loc=min, scale=max-min)
    return result

def runif(n, min=0, max=1):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(loc=min, scale=max-min, size=n)
    return result

# %%
print(f"Probability that a Uniform(0, 1) takes the value 0.5: {dunif(0.5)}")
print(f"Probability that a Uniform(0, 1) takes a value less than 0.5: {punif(0.5)}")
print(f"Which value of a Uniform(0, 1) has a cumulative probability of 0.9? {qunif(0.9)}")
print(f"Generate 5 random values from a Uniform(0, 1) distribution: {runif(5)}")
# Out:
# Probability that a Uniform(0, 1) takes the value 0.5: 1.0
# Probability that a Uniform(0, 1) takes a value less than 0.5: 0.5
# Which value of a Uniform(0, 1) has a cumulative probability of 0.9? 0.9
# Generate 5 random values from a Uniform(0, 1) distribution: [0.17440927 0.47164949 0.09142199 0.62568191 0.55053168]

# %%
# Parámetros para la distribución uniforme
min_val = 0
max_val = 1
n_samples = 2000

# Generar datos aleatorios de una distribución uniforme
data_uniform = runif(n_samples, min=min_val, max=max_val)

# Calcular PDF, CDF y PPF
pdf_uniform = dunif(data_uniform, min=min_val, max=max_val)
cdf_uniform = punif(data_uniform, min=min_val, max=max_val)
ppf_uniform = qunif(cdf_uniform, min=min_val, max=max_val)

# Crear gráficos
fig, axis = plt.subplots(3, 1, figsize=(7, 10))

axis[0].stem(data_uniform[:50], pdf_uniform[:50], 'r-')  # Gráfico PDF
axis[0].set_title('PDF - Uniform Distribution')

axis[1].stem(data_uniform[:50], cdf_uniform[:50], 'b-')  # Gráfico CDF
axis[1].set_title('CDF - Uniform Distribution')

axis[2].stem(data_uniform[:50], ppf_uniform[:50], 'g-')  # Gráfico PPF
axis[2].set_title('PPF - Uniform Distribution')

# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()
